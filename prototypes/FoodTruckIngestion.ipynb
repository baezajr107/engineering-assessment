# %%
import base64
import json
import requests
from datetime import datetime
from datetime import timedelta

# %%
# Get base data from the REST API
api_url = "https://data.sfgov.org/resource/rqzj-sfat.json"

try:

    api_response = requests.get(api_url)
    response_data = api_response.json()


except:
    print(api_response)

print(response_data)
# Out:
# [{'objectid': '735318', 'applicant': 'Ziaurehman Amini', 'facilitytype': 'Push Cart', 'cnn': '30727000', 'locationdescription': 'MARKET ST: DRUMM ST intersection', 'address': '5 THE EMBARCADERO', 'blocklot': '0234017', 'block': '0234', 'lot': '017', 'permit': '15MFF-0159', 'status': 'REQUESTED', 'x': '6013916.72', 'y': '2117244.027', 'latitude': '37.794331003246846', 'longitude': '-122.39581105302317', 'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0159&ExportPDF=1&Filename=15MFF-0159_schedule.pdf', 'received': '20151231', 'priorpermit': '0', 'expirationdate': '2016-03-15T00:00:00.000', 'location': {'latitude': '37.794331003246846', 'longitude': '-122.39581105302317', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_yftq_j783': '4', ':@computed_region_p5aj_wyqh': '1', ':@computed_region_rxqg_mtj9': '10', ':@computed_region_bh8s_q3mv': '28855', ':@computed_region_fyvs_ahh9': '6'}, {'objectid': '848184', 'applicant': 'Reecees Soulicious', 'facilitytype': 'Truck', 'cnn': '2799106', 'locationdescription': 'BAY SHORE BLVD: BAY SHORE BLVD to OAKDALE AVE (185 - 299) -- EAST --', 'address': '201 BAY SHORE BLVD', 'blocklot': '5559021', 'block': '5559', 'lot': '021', 'permit': '16MFF-0139', 'status': 'REQUESTED', 'fooditems': 'Fried Chicken: Fried Fish: Greens: Mac & Cheese: Peach Cobbler: and String beans', 'x': '6011355.555', 'y': '2099442.374', 'latitude': '37.74530890865633', 'longitude': '-122.40342005999852', 'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0139&ExportPDF=1&Filename=16MFF-0139_schedule.pdf', 'dayshours': 'Mo-We:7AM-7PM', 'received': '20160908', 'priorpermit': '0', 'expirationdate': '2017-03-15T00:00:00.000', 'location': {'latitude': '37.74530890865633', 'longitude': '-122.40342005999852', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_yftq_j783': '10', ':@computed_region_p5aj_wyqh': '3', ':@computed_region_rxqg_mtj9': '8', ':@computed_region_bh8s_q3mv': '58', ':@computed_region_fyvs_ahh9': '1'}, {'objectid': '1047831', 'applicant': 'The Chef Station', 'facilitytype': 'Truck', 'cnn': '480000', 'locationdescription': '10TH ST: FELL ST \\ MARKET ST \\ POLK ST to STEVENSON ST (1 - 18)', 'address': '8 10TH ST', 'blocklot': '3507041', 'block': '3507', 'lot': '041', 'permit': '17MFF-0203', 'status': 'REQUESTED', 'fooditems': 'South American/Peruvian food', 'x': '6007585.376', 'y': '2110633.378', 'latitude': '37.7758255197583', 'longitude': '-122.41724962664345', 'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0203&ExportPDF=1&Filename=17MFF-0203_schedule.pdf', 'received': '20171215', 'priorpermit': '0', 'location': {'latitude': '37.7758255197583', 'longitude': '-122.41724962664345', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_yftq_j783': '8', ':@computed_region_p5aj_wyqh': '2', ':@computed_region_rxqg_mtj9': '9', ':@computed_region_bh8s_q3mv': '28853', ':@computed_region_fyvs_ahh9': '34'}, {'objectid': '934516', 'applicant': 'Scotch Bonnet', 'facilitytype': 'Truck', 'cnn': '101000', 'locationdescription': '01ST ST: STEVENSON ST to JESSIE ST (21 - 56)', 'address': '50 01ST ST', 'blocklot': '3708055', 'block': '3708', 'lot': '055', 'permit': '17MFF-0094', 'status': 'EXPIRED', 'fooditems': 'Jerk chicken: curry chicken: curry goat: curry dhal: Burritos: Fish: Ox tails: rice: beans: veggies.', 'x': '6013063.33', 'y': '2115738.283', 'latitude': '37.790149073725544', 'longitude': '-122.39865818460403', 'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0094&ExportPDF=1&Filename=17MFF-0094_schedule.pdf', 'dayshours': 'Mo:6AM-8PM', 'approved': '2017-03-16T00:00:00.000', 'received': '20170213', 'priorpermi ...

# %%
print(response_data[0])
# Out:
# {'objectid': '735318', 'applicant': 'Ziaurehman Amini', 'facilitytype': 'Push Cart', 'cnn': '30727000', 'locationdescription': 'MARKET ST: DRUMM ST intersection', 'address': '5 THE EMBARCADERO', 'blocklot': '0234017', 'block': '0234', 'lot': '017', 'permit': '15MFF-0159', 'status': 'REQUESTED', 'x': '6013916.72', 'y': '2117244.027', 'latitude': '37.794331003246846', 'longitude': '-122.39581105302317', 'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0159&ExportPDF=1&Filename=15MFF-0159_schedule.pdf', 'received': '20151231', 'priorpermit': '0', 'expirationdate': '2016-03-15T00:00:00.000', 'location': {'latitude': '37.794331003246846', 'longitude': '-122.39581105302317', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_yftq_j783': '4', ':@computed_region_p5aj_wyqh': '1', ':@computed_region_rxqg_mtj9': '10', ':@computed_region_bh8s_q3mv': '28855', ':@computed_region_fyvs_ahh9': '6'}

# %%
import pandas as pd
from sodapy import Socrata

# trying out the python library provided by 
client = Socrata("data.sfgov.org", None)

results = client.get("rqzj-sfat")

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#     objectid                   applicant facilitytype       cnn  \
# 0     735318            Ziaurehman Amini    Push Cart  30727000
# 1     848184          Reecees Soulicious        Truck   2799106
# 2    1047831            The Chef Station        Truck    480000
# 3     934516               Scotch Bonnet        Truck    101000
# 4    1343454             Esmeli Catering        Truck   7022000
# ..       ...                         ...          ...       ...
# 476  1750856  TING TING MINI MOBILE DELI        Truck   2710000
# 477  1750860  TING TING MINI MOBILE DELI        Truck   5452000
# 478  1750861  TING TING MINI MOBILE DELI        Truck   5862000
# 479  1750835  TING TING MINI MOBILE DELI        Truck  10215000
# 480  1750864  TING TING MINI MOBILE DELI        Truck   6792000
#
#                                    locationdescription  \
# 0                     MARKET ST: DRUMM ST intersection
# 1    BAY SHORE BLVD: BAY SHORE BLVD to OAKDALE AVE ...
# 2    10TH ST: FELL ST \ MARKET ST \ POLK ST to STEV...
# 3         01ST ST: STEVENSON ST to JESSIE ST (21 - 56)
# 4            HOOPER ST: 07TH ST to 08TH ST (100 - 199)
# ..                                                 ...
# 476  BANCROFT AVE: JENNINGS ST to KEITH ST (1500 - ...
# 477    FELL ST: BRODERICK ST to BAKER ST (1300 - 1399)
# 478     FREMONT ST: NATOMA ST to HOWARD ST (170 - 199)
# 479    PALOU AVE: PALOU AVE to GRIFFITH ST (904 - 999)
# 480  HAWES ST: SHAFTER AVE to THOMAS AVE (1500 - 1599)
#
#                          address blocklot block  lot       permit  ...  \
# 0              5 THE EMBARCADERO  0234017  0234  017   15MFF-0159  ...
# 1             201 BAY SHORE BLVD  5559021  5559  021   16MFF-0139  ...
# 2                      8 10TH ST  3507041  3507  041   17MFF-0203  ...
# 3                     50 01ST ST  3708055  3708  055   17MFF-0094  ...
# 4           Assessors Block /Lot      NaN   NaN  NaN  19MFF-00110  ...
# ..                           ...      ...   ...  ...          ...  ...
# 476            1555 BANCROFT AVE  4880001  4880  001  23MFF-00054  ...
# 477                 1377 FELL ST  1214017  1214  017  23MFF-00054  ...
# 478  Assessors Block 3720/Lot001  3720001  3720  001  23MFF-00054  ...
# 479                931 PALOU AVE  4755042  4755  042  23MFF-00054  ...
# 480             1153 SHAFTER AVE  4793006  4793  006  23MFF-00054  ...
#
#               expirationdate  \
# 0    2016-03-15T00:00:00.000
# 1    2017-03-15T00:00:00.000
# 2                        NaN
# 3    2018-07-15T00:00:00.000
# 4                        NaN
# ..                       ...
# 476  2024-11-15T00:00:00.000
# 477  2024-11-15T00:00:00.000
# 478  2024-11-15T00:00:00.000
# 479  2024-11-15T00:00:00.000
# 480  2024-11-15T00:00:00.000
#
#                                               location  \
# 0    {'latitude': '37.794331003246846', 'longitude'...
# 1    {'latitude': '37.74530890865633', 'longitude':...
# 2    {'latitude': '37.7758255197583', 'longitude': ...
# 3    {'latitude': '37.790149073725544', 'longitude'...
# 4    {'latitude': '0.0', 'longitude': '0.0', 'human...
# ..                                                 ...
# 476  {'latitude': '37.72439752974338', 'longitude':...
# 477  {'latitude': '37.773287940470354', 'longitude'...
# 478  {'latitude': '37.78969136758703', 'longitude':...
# 479  {'latitude': '37.72673391124156', 'longitude':...
# 480  {'latitude': '37.72648516321647', 'longitude':...
#
#     :@computed_region_yftq_j783 :@computed_region_p5aj_wyqh  \
# 0                             4                           1
# 1                            10                           3
# 2                             8                           2
# 3                            12                           2
# 4                           NaN                         NaN
# ..                          ...                         ...
# 476                          10                           3
# 477                          15                           5
# 478                          12                           2
# 479                          10                           3
# 480                          10                           3
#
#     :@computed_region_rxqg_mtj9 :@computed_region_bh8s_q3mv  \
# 0                            10                       28855
# 1                             8                          58
# 2                             9                       28853
# 3                             9                       28855
# 4                           NaN                         NaN
# ..                          ...                         ...
# 476                           8                          58
# 477                          11                       29492
# 478                           9                       28855
# 479                           8                          58
# 480                           8                          58
#
#     :@computed_region_fyvs_ahh9  \
# 0                             6
# 1                             1
# 2                            34
# 3                             6
# 4                           NaN
# ..                          ...
# 476                           1
# 477                          10
# 478                           6
# 479                           1
# 480                           1
#
#                                              fooditems      dayshours  \
# 0                                                  NaN            NaN
# 1    Fried Chicken: Fried Fish: Greens: Mac & Chees...  Mo-We:7AM-7PM
# 2                         South American/Peruvian food            NaN
# 3    Jerk chicken: curry chicken: curry goat: curry...     Mo:6AM-8PM
# 4            tacos: burritos: quesadilla: tortas sodas            NaN
# ..                                                 ...            ...
# 476  Cold Truck: Pre-packaged sandwiches: snacks: f...            NaN
# 477  Cold Truck: Pre-packaged sandwiches: snacks: f...            NaN
# 478  Cold Truck: Pre-packaged sandwiches: snacks: f...            NaN
# 479  Cold Truck: Pre-packaged sandwiches: snacks: f...            NaN
# 480  Cold Truck: Pre-packaged sandwiches: snacks: f...            NaN
#
#                     approved
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3    2017-03-16T00:00:00.000
# 4                        NaN
# ..                       ...
# 476  2024-03-28T00:00:00.000
# 477  2024-03-28T00:00:00.000
# 478  2024-03-28T00:00:00.000
# 479  2024-03-28T00:00:00.000
# 480  2024-03-28T00:00:00.000
#
# [481 rows x 28 columns]

# %%
results_df.dtypes
# Out:
# objectid                       object
# applicant                      object
# facilitytype                   object
# cnn                            object
# locationdescription            object
# address                        object
# blocklot                       object
# block                          object
# lot                            object
# permit                         object
# status                         object
# x                              object
# y                              object
# latitude                       object
# longitude                      object
# schedule                       object
# received                       object
# priorpermit                    object
# expirationdate                 object
# location                       object
# :@computed_region_yftq_j783    object
# :@computed_region_p5aj_wyqh    object
# :@computed_region_rxqg_mtj9    object
# :@computed_region_bh8s_q3mv    object
# :@computed_region_fyvs_ahh9    object
# fooditems                      object
# dayshours                      object
# approved                       object
# dtype: object

# %%
print(type(results_df.iloc[0]['location']['latitude']))
print(type(results_df.iloc[0]['expirationdate']))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# going with the REST API for a few reasons:
#     it gives better control and visibility over deserialization and translation to our desired schema
#     better compatibility in the event that the code needs to be run in a locked down environment(only dependencies         in a pre-approved private repository are allowed)
#     Should the incoming data change, we don't need to rely on them updating their client libraries to continue our         functionality
# If the process was any more complicated I would go with the library

# %%
output_data=[]
date_format='%Y-%m-%dT%H:%M:%S.%f'
# Transform the data into the proper types and column names
for data in response_data:
    output_data.append(
    {
        'location_id' : data['objectid'],
        'applicant' : data['applicant'],
        'facility_type' : data['facilitytype'] if 'facilitytype' in data else None,
        'cnn' : int(data['cnn']),
        'location_description' : data['locationdescription'] if 'locationdescription' in data else None,
        'address' : data['address'],
        'blocklot' : data['blocklot'] if 'blocklot' in data else None,
        'block' : data['block'] if 'block' in data else None,
        'lot' : data['lot'] if 'lot' in data else None,
        'permit' : data['permit'],
        'status' : data['status'],
        'food_items' : data['fooditems'] if 'fooditems' in data else None,
        'x' : float(data['x']) if 'x' in data else None,
        'y' : float(data['y']) if 'y' in data else None,
        'latitude' : float(data['latitude']),
        'longitude' : float(data['longitude']),
        'schedule' : data['schedule'],
        'dayshours' : data['dayshours'] if 'dayshours' in data else None,
        'approved' : datetime.strptime(data['approved'], date_format) if 'approved' in data else None,
        'received' : data['received'],
        'prior_permit' : True if data['priorpermit'] == '1' else False,
        'expiration_date' : datetime.strptime(data['expirationdate'], date_format) if 'expirationdate' in data else None
    }
    )

# %%
output_data
# Out:
# [{'location_id': '735318',
#   'applicant': 'Ziaurehman Amini',
#   'facility_type': 'Push Cart',
#   'cnn': 30727000,
#   'location_description': 'MARKET ST: DRUMM ST intersection',
#   'address': '5 THE EMBARCADERO',
#   'blocklot': '0234017',
#   'block': '0234',
#   'lot': '017',
#   'permit': '15MFF-0159',
#   'status': 'REQUESTED',
#   'food_items': None,
#   'x': 6013916.72,
#   'y': 2117244.027,
#   'latitude': 37.794331003246846,
#   'longitude': -122.39581105302317,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0159&ExportPDF=1&Filename=15MFF-0159_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20151231',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2016, 3, 15, 0, 0)},
#  {'location_id': '848184',
#   'applicant': 'Reecees Soulicious',
#   'facility_type': 'Truck',
#   'cnn': 2799106,
#   'location_description': 'BAY SHORE BLVD: BAY SHORE BLVD to OAKDALE AVE (185 - 299) -- EAST --',
#   'address': '201 BAY SHORE BLVD',
#   'blocklot': '5559021',
#   'block': '5559',
#   'lot': '021',
#   'permit': '16MFF-0139',
#   'status': 'REQUESTED',
#   'food_items': 'Fried Chicken: Fried Fish: Greens: Mac & Cheese: Peach Cobbler: and String beans',
#   'x': 6011355.555,
#   'y': 2099442.374,
#   'latitude': 37.74530890865633,
#   'longitude': -122.40342005999852,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0139&ExportPDF=1&Filename=16MFF-0139_schedule.pdf',
#   'dayshours': 'Mo-We:7AM-7PM',
#   'approved': None,
#   'received': '20160908',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2017, 3, 15, 0, 0)},
#  {'location_id': '1047831',
#   'applicant': 'The Chef Station',
#   'facility_type': 'Truck',
#   'cnn': 480000,
#   'location_description': '10TH ST: FELL ST \\ MARKET ST \\ POLK ST to STEVENSON ST (1 - 18)',
#   'address': '8 10TH ST',
#   'blocklot': '3507041',
#   'block': '3507',
#   'lot': '041',
#   'permit': '17MFF-0203',
#   'status': 'REQUESTED',
#   'food_items': 'South American/Peruvian food',
#   'x': 6007585.376,
#   'y': 2110633.378,
#   'latitude': 37.7758255197583,
#   'longitude': -122.41724962664345,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0203&ExportPDF=1&Filename=17MFF-0203_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20171215',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '934516',
#   'applicant': 'Scotch Bonnet',
#   'facility_type': 'Truck',
#   'cnn': 101000,
#   'location_description': '01ST ST: STEVENSON ST to JESSIE ST (21 - 56)',
#   'address': '50 01ST ST',
#   'blocklot': '3708055',
#   'block': '3708',
#   'lot': '055',
#   'permit': '17MFF-0094',
#   'status': 'EXPIRED',
#   'food_items': 'Jerk chicken: curry chicken: curry goat: curry dhal: Burritos: Fish: Ox tails: rice: beans: veggies.',
#   'x': 6013063.33,
#   'y': 2115738.283,
#   'latitude': 37.790149073725544,
#   'longitude': -122.39865818460403,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0094&ExportPDF=1&Filename=17MFF-0094_schedule.pdf',
#   'dayshours': 'Mo:6AM-8PM',
#   'approved': datetime.datetime(2017, 3, 16, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '1343454',
#   'applicant': 'Esmeli Catering',
#   'facility_type': 'Truck',
#   'cnn': 7022000,
#   'location_description': 'HOOPER ST: 07TH ST to 08TH ST (100 - 199)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '19MFF-00110',
#   'status': 'REQUESTED',
#   'food_items': 'tacos: burritos: quesadilla: tortas sodas',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00110&ExportPDF=1&Filename=19MFF-00110_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190731',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1334819',
#   'applicant': 'tacos y pupusas los trinos',
#   'facility_type': None,
#   'cnn': 9158000,
#   'location_description': 'MISSION ST: AVALON AVE to COTTER ST (4368 - 4439)',
#   'address': '4384 MISSION ST',
#   'blocklot': '6798004',
#   'block': '6798',
#   'lot': '004',
#   'permit': '19MFF-00048',
#   'status': 'REQUESTED',
#   'food_items': None,
#   'x': 6002680.03,
#   'y': 2093158.531,
#   'latitude': 37.727566537591706,
#   'longitude': -122.4329697019889,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00048&ExportPDF=1&Filename=19MFF-00048_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190703',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '755221',
#   'applicant': 'Fruteria Serrano',
#   'facility_type': None,
#   'cnn': 9167000,
#   'location_description': 'MISSION ST: OCEAN AVE to PERSIA AVE (4650 - 4699)',
#   'address': '4650 MISSION ST',
#   'blocklot': '6955044',
#   'block': '6955',
#   'lot': '044',
#   'permit': '16MFF-0011',
#   'status': 'REQUESTED',
#   'food_items': 'Fruits including mangoes: pineapples: coconuts: watermelon: corn: cucumber: potatoes chips: water: Mexican drinks: sodas: juices: snow cones',
#   'x': 6001790.666,
#   'y': 2091754.638,
#   'latitude': 37.723661279505265,
#   'longitude': -122.43594382523997,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0011&ExportPDF=1&Filename=16MFF-0011_schedule.pdf',
#   'dayshours': 'Mo/Th/Fr:11AM-6PM',
#   'approved': None,
#   'received': '20160217',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2017, 3, 15, 0, 0)},
#  {'location_id': '1337787',
#   'applicant': 'Giant Burrito',
#   'facility_type': 'Truck',
#   'cnn': 6148201,
#   'location_description': 'GENEVA AVE: PRAGUE ST to LINDA VISTA STPS (1500 - 1598) -- SOUTH --',
#   'address': '1500 GENEVA AVE',
#   'blocklot': '6418065',
#   'block': '6418',
#   'lot': '065',
#   'permit': '19MFF-00088',
#   'status': 'REQUESTED',
#   'food_items': 'Tacos: Burritos: Tostadas: Flautas: Tostadas: Tortas: Pozole Menudo',
#   'x': 6002948.585,
#   'y': 2087593.93,
#   'latitude': 37.712302604744416,
#   'longitude': -122.43164419037294,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00088&ExportPDF=1&Filename=19MFF-00088_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190715',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 7, 15, 0, 0)},
#  {'location_id': '1367290',
#   'applicant': 'Star Taco',
#   'facility_type': None,
#   'cnn': 7034000,
#   'location_description': 'HOWARD ST: MALDEN ALY to 02ND ST (574 - 599)',
#   'address': '580 HOWARD ST',
#   'blocklot': '3721092',
#   'block': '3721',
#   'lot': '092',
#   'permit': '19MFF-00128',
#   'status': 'REQUESTED',
#   'food_items': 'Mexican Food',
#   'x': 6013221.712,
#   'y': 2114698.993,
#   'latitude': 37.7873042488646,
#   'longitude': -122.39803725191237,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00128&ExportPDF=1&Filename=19MFF-00128_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20191009',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 7, 15, 0, 0)},
#  {'location_id': '934518',
#   'applicant': 'Scotch Bonnet',
#   'facility_type': 'Truck',
#   'cnn': 11543000,
#   'location_description': 'SANSOME ST: BUSH ST to PINE ST (100 - 199)',
#   'address': '115 SANSOME ST',
#   'blocklot': '0268002',
#   'block': '0268',
#   'lot': '002',
#   'permit': '17MFF-0094',
#   'status': 'EXPIRED',
#   'food_items': 'Jerk chicken: curry chicken: curry goat: curry dhal: Burritos: Fish: Ox tails: rice: beans: veggies.',
#   'x': 6012385.284,
#   'y': 2116217.3,
#   'latitude': 37.79142654133214,
#   'longitude': -122.40103785668795,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0094&ExportPDF=1&Filename=17MFF-0094_schedule.pdf',
#   'dayshours': 'Fr:6AM-8PM',
#   'approved': datetime.datetime(2017, 3, 16, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '812017',
#   'applicant': 'SF Street Food',
#   'facility_type': 'Truck',
#   'cnn': 12320000,
#   'location_description': 'SUTTER ST: CLAUDE LN to GRANT AVE (216 - 299)',
#   'address': '290 SUTTER ST',
#   'blocklot': '0287014',
#   'block': '0287',
#   'lot': '014',
#   'permit': '16MFF-0126',
#   'status': 'REQUESTED',
#   'food_items': 'Chicken Tikka Masala: Vegetarian Rice Plate: Burritos: Tacos: Mango Lassi',
#   'x': 6011162.135,
#   'y': 2115691.265,
#   'latitude': 37.78991386713444,
#   'longitude': -122.40523289252366,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0126&ExportPDF=1&Filename=16MFF-0126_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20160531',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1344202',
#   'applicant': 'Bay Area Dots, LLC',
#   'facility_type': 'Push Cart',
#   'cnn': 2846000,
#   'location_description': 'BEACH ST: HYDE ST to LARKIN ST (700 - 799)',
#   'address': '900 BEACH ST',
#   'blocklot': '0405007',
#   'block': '0405',
#   'lot': '007',
#   'permit': '19MFF-00116',
#   'status': 'REQUESTED',
#   'food_items': 'Hot dogs: condiments: soft pretzels: soft drinks: coffee:cold beverages: pastries: bakery goods: cookies: icecream: candy: soups: churros: chestnuts: nuts: fresh fruit: fruit juices: desserts: potato chips and popcorn.',
#   'x': 6005830.41439,
#   'y': 2122293.82162,
#   'latitude': 37.80774328844553,
#   'longitude': -122.42414994486982,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00116&ExportPDF=1&Filename=19MFF-00116_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190802',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2020, 7, 15, 0, 0)},
#  {'location_id': '1359707',
#   'applicant': 'Union Square Business Improvement District',
#   'facility_type': 'Truck',
#   'cnn': 8626000,
#   'location_description': 'MAIDEN LN: GRANT AVE to STOCKTON ST (100 - 199)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '19MFF-00125',
#   'status': 'REQUESTED',
#   'food_items': "All types of food except for BBQ on site per fire safety. Partnership with Off the Grid and their fleet of MFF's",
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00125&ExportPDF=1&Filename=19MFF-00125_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190920',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 7, 15, 0, 0)},
#  {'location_id': '1265606',
#   'applicant': "San Francisco Carts & Concessions, Inc. DBA Stanley's Steamers Hot Dogs",
#   'facility_type': 'Push Cart',
#   'cnn': 10628000,
#   'location_description': 'POST ST: STOCKTON ST to POWELL ST (300 - 399)',
#   'address': '384 POST ST',
#   'blocklot': '0295007',
#   'block': '0295',
#   'lot': '007',
#   'permit': '19MFF-00001',
#   'status': 'REQUESTED',
#   'food_items': 'American Food: Hot dogs: pretzels: ice cream: salads: beverages: sandwiches: soup: coffee: pastries:etc.',
#   'x': 6010333.205,
#   'y': 2115237.376,
#   'latitude': 37.78862121908618,
#   'longitude': -122.40806890640651,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00001&ExportPDF=1&Filename=19MFF-00001_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190107',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 1, 7, 0, 0)},
#  {'location_id': '955616',
#   'applicant': 'Tacos Santo Toribio',
#   'facility_type': 'Truck',
#   'cnn': 12628000,
#   'location_description': 'TOLAND ST: NEWCOMB AVE to OAKDALE AVE (900 - 999)',
#   'address': '928 TOLAND ST',
#   'blocklot': '5597A001',
#   'block': '5597A',
#   'lot': '001',
#   'permit': '17MFF-0171',
#   'status': 'REQUESTED',
#   'food_items': 'tacos',
#   'x': 6011869.691,
#   'y': 2098089.783,
#   'latitude': 37.74162368623527,
#   'longitude': -122.4015472063967,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0171&ExportPDF=1&Filename=17MFF-0171_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20170323',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '848185',
#   'applicant': 'Reecees Soulicious',
#   'facility_type': 'Truck',
#   'cnn': 211101,
#   'location_description': '03RD ST: NEWCOMB AVE to OAKDALE AVE (4701 - 4799) -- EAST --',
#   'address': '4705 03RD ST',
#   'blocklot': '5311036',
#   'block': '5311',
#   'lot': '036',
#   'permit': '16MFF-0139',
#   'status': 'REQUESTED',
#   'food_items': 'Fried Chicken: Fried Fish: Greens: Mac & Cheese: Peach Cobbler: and String beans',
#   'x': 6015109.358,
#   'y': 2095613.38,
#   'latitude': 37.735004228951425,
#   'longitude': -122.39017246969969,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0139&ExportPDF=1&Filename=16MFF-0139_schedule.pdf',
#   'dayshours': 'Th/Fr/Sa:7AM-7PM',
#   'approved': None,
#   'received': '20160908',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2017, 3, 15, 0, 0)},
#  {'location_id': '848080',
#   'applicant': 'Taqueria Lolita',
#   'facility_type': 'Truck',
#   'cnn': 10927000,
#   'location_description': 'RANKIN ST: DAVIDSON AVE to EVANS AVE (200 - 299)',
#   'address': '1700 EVANS AVE',
#   'blocklot': '5227001',
#   'block': '5227',
#   'lot': '001',
#   'permit': '16MFF-0128',
#   'status': 'SUSPEND',
#   'food_items': 'Tacos: burritos: quesadillas: combination plates: tortas: tostadas',
#   'x': 6014950.929,
#   'y': 2099216.653,
#   'latitude': 37.744889286143,
#   'longitude': -122.39097197693538,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0128&ExportPDF=1&Filename=16MFF-0128_schedule.pdf',
#   'dayshours': 'Th/Fr/Sa:7AM-3PM',
#   'approved': datetime.datetime(2017, 8, 1, 0, 0),
#   'received': '20160622',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 3, 15, 0, 0)},
#  {'location_id': '1010174',
#   'applicant': "Julie's Hot Dogs",
#   'facility_type': 'Truck',
#   'cnn': 9121000,
#   'location_description': 'MISSION ST: 19TH ST to 20TH ST (2300 - 2399)',
#   'address': '2386 MISSION ST',
#   'blocklot': '3596119',
#   'block': '3596',
#   'lot': '119',
#   'permit': '15MFF-0007',
#   'status': 'REQUESTED',
#   'food_items': 'Hot dogs: bacon-wrapped hot dogs: chicken burgers: energy drinks: water and various other drinks.',
#   'x': 6006843.48,
#   'y': 2104477.073,
#   'latitude': 37.75887999201479,
#   'longitude': -122.41937920298372,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0007&ExportPDF=1&Filename=15MFF-0007_schedule.pdf',
#   'dayshours': 'Tu/We/Th:12AM-3AM;Mo-We:12PM-12AM',
#   'approved': None,
#   'received': '20150223',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1265597',
#   'applicant': "San Francisco Carts & Concessions, Inc. DBA Stanley's Steamers Hot Dogs",
#   'facility_type': 'Push Cart',
#   'cnn': 10628000,
#   'location_description': 'POST ST: STOCKTON ST to POWELL ST (300 - 399)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '19MFF-00001',
#   'status': 'REQUESTED',
#   'food_items': 'American Food: Hot dogs: pretzels: ice cream: salads: beverages: sandwiches: soup: coffee: pastries:etc.',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00001&ExportPDF=1&Filename=19MFF-00001_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190107',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 1, 7, 0, 0)},
#  {'location_id': '627558',
#   'applicant': 'Off the Grid Services, LLC',
#   'facility_type': 'Truck',
#   'cnn': 4609000,
#   'location_description': 'DAVIS ST: DAVIS CT \\ JACKSON ST to BROADWAY (500 - 699)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '15MFF-0039',
#   'status': 'REQUESTED',
#   'food_items': 'varies truck to truck',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0039&ExportPDF=1&Filename=15MFF-0039_schedule.pdf',
#   'dayshours': 'Tu/Th/Fr:10AM-3PM',
#   'approved': None,
#   'received': '20150306',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '364218',
#   'applicant': 'The Chai Cart',
#   'facility_type': 'Push Cart',
#   'cnn': 9543000,
#   'location_description': 'NEW MONTGOMERY ST: AMBROSE BIERCE ST to MISSION ST (77 - 99)',
#   'address': '79 NEW MONTGOMERY ST',
#   'blocklot': '3707014',
#   'block': '3707',
#   'lot': '014',
#   'permit': '12MFF-0083',
#   'status': 'SUSPEND',
#   'food_items': 'Hot Indian Chai (Tea)',
#   'x': 6012504.312,
#   'y': 2114926.774,
#   'latitude': 37.78788969990609,
#   'longitude': -122.40053532677749,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=12MFF-0083&ExportPDF=1&Filename=12MFF-0083_schedule.pdf',
#   'dayshours': 'Mo-Su:7AM-6PM',
#   'approved': None,
#   'received': '20120403',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '931093',
#   'applicant': 'Swell Cream & Coffee',
#   'facility_type': 'Truck',
#   'cnn': 12412000,
#   'location_description': 'TARAVAL ST: 36TH AVE to SUNSET BLVD (2600 - 2649)',
#   'address': '2401 36TH AVE',
#   'blocklot': '2389001',
#   'block': '2389',
#   'lot': '001',
#   'permit': '17MFF-0002',
#   'status': 'REQUESTED',
#   'food_items': 'Ice cream: coffee: pastries',
#   'x': 5985030.8,
#   'y': 2098527.088,
#   'latitude': 37.7412902847707,
#   'longitude': -122.49437792043544,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0002&ExportPDF=1&Filename=17MFF-0002_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20170130',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 1, 30, 0, 0)},
#  {'location_id': '997504',
#   'applicant': 'Munch India',
#   'facility_type': 'Truck',
#   'cnn': 10624001,
#   'location_description': 'POST ST: MONTGOMERY ST to LICK PL (1 - 40)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '17MFF-0187',
#   'status': 'REQUESTED',
#   'food_items': 'Daily rotating menus consisting of various local & organic vegetable: poultry: meat: seafood : rice & bread dishes.',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0187&ExportPDF=1&Filename=17MFF-0187_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20170719',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2017, 7, 19, 0, 0)},
#  {'location_id': '773095',
#   'applicant': 'Athena SF Gyro',
#   'facility_type': 'Push Cart',
#   'cnn': 30747000,
#   'location_description': 'MARKET ST: 11TH ST intersection',
#   'address': '10 SOUTH VAN NESS AVE',
#   'blocklot': '3506004',
#   'block': '3506',
#   'lot': '004',
#   'permit': '15MFF-0145',
#   'status': 'REQUESTED',
#   'food_items': 'Gyro pita bread (Lamb or chicken): lamb over rice: chicken over rice: chicken biryani rice: soft drinks',
#   'x': 6006927.466,
#   'y': 2110076.439,
#   'latitude': 37.77425926306004,
#   'longitude': -122.41948598839828,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0145&ExportPDF=1&Filename=15MFF-0145_schedule.pdf',
#   'dayshours': 'We/Th/Fr:6AM-6PM',
#   'approved': None,
#   'received': '20150901',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '934552',
#   'applicant': "Casey's Pizza, LLC",
#   'facility_type': 'Truck',
#   'cnn': 9093000,
#   'location_description': 'MISSION ST: NEW MONTGOMERY ST to ANNIE ST (635 - 664)',
#   'address': '654 MISSION ST',
#   'blocklot': '3707019',
#   'block': '3707',
#   'lot': '019',
#   'permit': '17MFF-0104',
#   'status': 'EXPIRED',
#   'food_items': "Artisan Pizzas (Margherita: Yukon Potato: Zoe's Pepperoni: Funghi: Brocolli Rabe: Bacon Kale:  Arugula) and Drinks.",
#   'x': 6012296.995,
#   'y': 2114673.552,
#   'latitude': 37.78718284771541,
#   'longitude': -122.40123480885063,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0104&ExportPDF=1&Filename=17MFF-0104_schedule.pdf',
#   'dayshours': 'Fr:11AM-3PM',
#   'approved': datetime.datetime(2017, 8, 29, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '934517',
#   'applicant': 'Scotch Bonnet',
#   'facility_type': 'Truck',
#   'cnn': 9297000,
#   'location_description': 'MONTGOMERY ST: POST ST to SUTTER ST (1 - 99)',
#   'address': '25 MONTGOMERY ST',
#   'blocklot': '0292001A',
#   'block': '0292',
#   'lot': '001A',
#   'permit': '17MFF-0094',
#   'status': 'EXPIRED',
#   'food_items': 'Jerk chicken: curry chicken: curry goat: curry dhal: Burritos: Fish: Ox tails: rice: beans: veggies.',
#   'x': 6011957.923,
#   'y': 2115519.499,
#   'latitude': 37.78948669612784,
#   'longitude': -122.40246743800449,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0094&ExportPDF=1&Filename=17MFF-0094_schedule.pdf',
#   'dayshours': 'We:6AM-8PM',
#   'approved': datetime.datetime(2017, 3, 16, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '1089427',
#   'applicant': 'Halal Food',
#   'facility_type': 'Push Cart',
#   'cnn': 3524000,
#   'location_description': 'CALIFORNIA ST: DRUMM ST to DAVIS ST (1 - 99)',
#   'address': '50 CALIFORNIA ST',
#   'blocklot': '0235022',
#   'block': '0235',
#   'lot': '022',
#   'permit': '18MFF-0003',
#   'status': 'REQUESTED',
#   'food_items': "rice chicken beef hot dogs and sandwich's and coke and water",
#   'x': 6013470.754,
#   'y': 2117151.885,
#   'latitude': 37.79405318373291,
#   'longitude': -122.39734769332577,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=18MFF-0003&ExportPDF=1&Filename=18MFF-0003_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20180205',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2019, 2, 28, 0, 0)},
#  {'location_id': '934554',
#   'applicant': "Casey's Pizza, LLC",
#   'facility_type': 'Truck',
#   'cnn': 12045000,
#   'location_description': 'SPEAR ST: MISSION ST to HOWARD ST (100 - 199)',
#   'address': '100 SPEAR ST',
#   'blocklot': '3717001',
#   'block': '3717',
#   'lot': '001',
#   'permit': '17MFF-0104',
#   'status': 'EXPIRED',
#   'food_items': "Artisan Pizzas (Margherita: Yukon Potato: Zoe's Pepperoni: Funghi: Brocolli Rabe: Bacon Kale:  Arugula) and Drinks.",
#   'x': 6014423.85,
#   'y': 2116439.642,
#   'latitude': 37.792150548481686,
#   'longitude': -122.39399997405945,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0104&ExportPDF=1&Filename=17MFF-0104_schedule.pdf',
#   'dayshours': 'Tu/Th:9AM-3PM',
#   'approved': datetime.datetime(2017, 8, 29, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '934551',
#   'applicant': "Casey's Pizza, LLC",
#   'facility_type': 'Truck',
#   'cnn': 5442000,
#   'location_description': 'FELL ST: GOUGH ST to OCTAVIA ST (300 - 399)',
#   'address': '368 FELL ST',
#   'blocklot': '0817032',
#   'block': '0817',
#   'lot': '032',
#   'permit': '17MFF-0104',
#   'status': 'EXPIRED',
#   'food_items': "Artisan Pizzas (Margherita: Yukon Potato: Zoe's Pepperoni: Funghi: Brocolli Rabe: Bacon Kale:  Arugula) and Drinks.",
#   'x': 6005654.042,
#   'y': 2110754.304,
#   'latitude': 37.77604870809225,
#   'longitude': -122.42393921117214,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0104&ExportPDF=1&Filename=17MFF-0104_schedule.pdf',
#   'dayshours': 'Su:12PM-8PM;Fr:3PM-8PM;Sa:4PM-8PM',
#   'approved': datetime.datetime(2017, 8, 29, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '934555',
#   'applicant': "Casey's Pizza, LLC",
#   'facility_type': 'Truck',
#   'cnn': 11544000,
#   'location_description': 'SANSOME ST: PINE ST to CALIFORNIA ST (200 - 299)',
#   'address': '231 SANSOME ST',
#   'blocklot': '0260002',
#   'block': '0260',
#   'lot': '002',
#   'permit': '17MFF-0104',
#   'status': 'EXPIRED',
#   'food_items': "Artisan Pizzas (Margherita: Yukon Potato: Zoe's Pepperoni: Funghi: Brocolli Rabe: Bacon Kale:  Arugula) and Drinks.",
#   'x': 6012313.995,
#   'y': 2116649.543,
#   'latitude': 37.792609401119016,
#   'longitude': -122.40131490545147,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0104&ExportPDF=1&Filename=17MFF-0104_schedule.pdf',
#   'dayshours': 'Mo/We:10AM-2PM',
#   'approved': datetime.datetime(2017, 8, 29, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '773105',
#   'applicant': 'Athena SF Gyro',
#   'facility_type': 'Push Cart',
#   'cnn': 417000,
#   'location_description': '08TH ST: BRANNAN ST to TOWNSEND ST (600 - 699)',
#   'address': '699 08TH ST',
#   'blocklot': '3783009',
#   'block': '3783',
#   'lot': '009',
#   'permit': '15MFF-0145',
#   'status': 'REQUESTED',
#   'food_items': 'Gyro pita bread (Lamb or chicken): lamb over rice: chicken over rice: chicken biryani rice: soft drinks',
#   'x': 6011509.501,
#   'y': 2108803.834,
#   'latitude': 37.771021999243686,
#   'longitude': -122.4035462541838,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0145&ExportPDF=1&Filename=15MFF-0145_schedule.pdf',
#   'dayshours': 'Mo-We:6AM-6PM',
#   'approved': None,
#   'received': '20150901',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '839523',
#   'applicant': 'Halal Cart of San Francisco',
#   'facility_type': 'Push Cart',
#   'cnn': 8741201,
#   'location_description': 'MARKET ST: FREMONT ST \\ FRONT ST to 01ST ST \\ BUSH ST (400 - 498) -- NORTH --',
#   'address': '1 FRONT ST',
#   'blocklot': '0266009',
#   'block': '0266',
#   'lot': '009',
#   'permit': '16MFF-0136',
#   'status': 'REQUESTED',
#   'food_items': 'Gyro; Chicken over rice; Gyro over rice;',
#   'x': 6013006.032,
#   'y': 2116325.123,
#   'latitude': 37.791757205944414,
#   'longitude': -122.39889763689186,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0136&ExportPDF=1&Filename=16MFF-0136_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20160812',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '837171',
#   'applicant': 'Chilifruit',
#   'facility_type': 'Push Cart',
#   'cnn': 1346000,
#   'location_description': '24TH ST: MISSION ST to OSAGE ALY (3300 - 3322)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '16MFF-0135',
#   'status': 'REQUESTED',
#   'food_items': 'Mangoneadas: Fruit snacks: Chamoyadas: Bionicos',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0135&ExportPDF=1&Filename=16MFF-0135_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20160805',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1265569',
#   'applicant': "San Francisco Carts & Concessions, Inc. DBA Stanley's Steamers Hot Dogs",
#   'facility_type': 'Push Cart',
#   'cnn': 10678000,
#   'location_description': 'POWELL ST: GEARY ST to POST ST (300 - 399)',
#   'address': '331 POWELL ST',
#   'blocklot': '0307001',
#   'block': '0307',
#   'lot': '001',
#   'permit': '19MFF-00001',
#   'status': 'REQUESTED',
#   'food_items': 'American Food: Hot dogs: pretzels: ice cream: salads: beverages: sandwiches: soup: coffee: pastries:etc.',
#   'x': 6010120.694,
#   'y': 2114926.344,
#   'latitude': 37.787755298967475,
#   'longitude': -122.40878221396503,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00001&ExportPDF=1&Filename=19MFF-00001_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190107',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 1, 7, 0, 0)},
#  {'location_id': '839524',
#   'applicant': 'Halal Cart of San Francisco',
#   'facility_type': 'Push Cart',
#   'cnn': 8742101,
#   'location_description': 'MARKET ST: 01ST ST \\ BUSH ST to 02ND ST (501 - 599) -- SOUTH --',
#   'address': '555 MARKET ST',
#   'blocklot': '3708057',
#   'block': '3708',
#   'lot': '057',
#   'permit': '16MFF-0136',
#   'status': 'REQUESTED',
#   'food_items': 'Gyro; Chicken over rice; Gyro over rice;',
#   'x': 6012693.864,
#   'y': 2115651.384,
#   'latitude': 37.78988987820978,
#   'longitude': -122.39993041135052,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0136&ExportPDF=1&Filename=16MFF-0136_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20160812',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1141511',
#   'applicant': 'Khalid M Malik',
#   'facility_type': 'Push Cart',
#   'cnn': 2751000,
#   'location_description': 'BATTERY ST: MARKET ST to BUSH ST (1 - 10)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '18MFF-0018',
#   'status': 'REQUESTED',
#   'food_items': 'chicken sandwich: chicken gyro: chicken biryani',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=18MFF-0018&ExportPDF=1&Filename=18MFF-0018_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20180412',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1047771',
#   'applicant': 'The Chef Station',
#   'facility_type': None,
#   'cnn': 4801101,
#   'location_description': 'DIVISADERO ST: OAK ST to FELL ST (401 - 499) -- WEST --',
#   'address': '425 DIVISADERO ST',
#   'blocklot': '1215016',
#   'block': '1215',
#   'lot': '016',
#   'permit': '17MFF-0202',
#   'status': 'REQUESTED',
#   'food_items': 'South American Peruvian Food - Ceiches: hot wok dishes: hot pastas: rice dishes: and Tapas.',
#   'x': 6001606.909,
#   'y': 2109860.071,
#   'latitude': 37.77336405319086,
#   'longitude': -122.43787522530337,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0202&ExportPDF=1&Filename=17MFF-0202_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20171215',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '934519',
#   'applicant': 'Scotch Bonnet',
#   'facility_type': 'Truck',
#   'cnn': 3528000,
#   'location_description': 'CALIFORNIA ST: SANSOME ST to LEIDESDORFF ST (400 - 448)',
#   'address': '430 CALIFORNIA ST',
#   'blocklot': '0239029',
#   'block': '0239',
#   'lot': '029',
#   'permit': '17MFF-0094',
#   'status': 'EXPIRED',
#   'food_items': 'Jerk chicken: curry chicken: curry goat: curry dhal: Burritos: Fish: Ox tails: rice: beans: veggies.',
#   'x': 6012181.836,
#   'y': 2116889.979,
#   'latitude': 37.793262206923096,
#   'longitude': -122.4017890913628,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0094&ExportPDF=1&Filename=17MFF-0094_schedule.pdf',
#   'dayshours': 'Tu/Th:6AM-8PM',
#   'approved': datetime.datetime(2017, 3, 16, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '812018',
#   'applicant': 'SF Street Food',
#   'facility_type': 'Truck',
#   'cnn': 9094000,
#   'location_description': 'MISSION ST: ANNIE ST to 03RD ST (663 - 699)',
#   'address': '667 MISSION ST',
#   'blocklot': '3722067',
#   'block': '3722',
#   'lot': '067',
#   'permit': '16MFF-0126',
#   'status': 'REQUESTED',
#   'food_items': 'Chicken Tikka Masala: Vegetarian Rice Plate: Burritos: Tacos: Mango Lassi',
#   'x': 6012350.571,
#   'y': 2114444.914,
#   'latitude': 37.7865580501799,
#   'longitude': -122.40103337534973,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0126&ExportPDF=1&Filename=16MFF-0126_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20160531',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '931094',
#   'applicant': 'Swell Cream & Coffee',
#   'facility_type': 'Truck',
#   'cnn': 12410000,
#   'location_description': 'TARAVAL ST: 34TH AVE to 35TH AVE (2400 - 2499)',
#   'address': '2450 TARAVAL ST',
#   'blocklot': '2363022',
#   'block': '2363',
#   'lot': '022',
#   'permit': '17MFF-0002',
#   'status': 'REQUESTED',
#   'food_items': 'Ice cream: coffee: pastries',
#   'x': 5985532.259,
#   'y': 2098975.331,
#   'latitude': 37.74255037355925,
#   'longitude': -122.49267708221483,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0002&ExportPDF=1&Filename=17MFF-0002_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20170130',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 1, 30, 0, 0)},
#  {'location_id': '1265607',
#   'applicant': "San Francisco Carts & Concessions, Inc. DBA Stanley's Steamers Hot Dogs",
#   'facility_type': 'Push Cart',
#   'cnn': 6109000,
#   'location_description': 'GEARY ST: STOCKTON ST to POWELL ST (200 - 299)',
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '19MFF-00001',
#   'status': 'REQUESTED',
#   'food_items': 'American Food: Hot dogs: pretzels: ice cream: salads: beverages: sandwiches: soup: coffee: pastries:etc.',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00001&ExportPDF=1&Filename=19MFF-00001_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190107',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 1, 7, 0, 0)},
#  {'location_id': '840504',
#   'applicant': 'Taqueria Lolita',
#   'facility_type': 'Truck',
#   'cnn': 5336000,
#   'location_description': 'EVANS AVE: QUINT ST to RANKIN ST (1700 - 1799)',
#   'address': '750 PHELPS ST',
#   'blocklot': '5280001',
#   'block': '5280',
#   'lot': '001',
#   'permit': '16MFF-0128',
#   'status': 'SUSPEND',
#   'food_items': 'Tacos: burritos: quesadillas: combination plates: tortas: tostadas',
#   'x': 6014320.244,
#   'y': 2097246.796,
#   'latitude': 37.73944545286909,
#   'longitude': -122.39301498669842,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0128&ExportPDF=1&Filename=16MFF-0128_schedule.pdf',
#   'dayshours': 'Mo-We:7AM-3PM',
#   'approved': datetime.datetime(2017, 8, 1, 0, 0),
#   'received': '20160622',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 3, 15, 0, 0)},
#  {'location_id': '735315',
#   'applicant': 'Ziaurehman Amini',
#   'facility_type': 'Push Cart',
#   'cnn': 4969000,
#   'location_description': 'DRUMM ST: MARKET ST to CALIFORNIA ST (1 - 6)',
#   'address': '1 CALIFORNIA ST',
#   'blocklot': '0264004',
#   'block': '0264',
#   'lot': '004',
#   'permit': '15MFF-0159',
#   'status': 'REQUESTED',
#   'food_items': None,
#   'x': 6013552.57,
#   'y': 2116844.5,
#   'latitude': 37.793213731663414,
#   'longitude': -122.39704303671823,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0159&ExportPDF=1&Filename=15MFF-0159_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20151231',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2016, 3, 15, 0, 0)},
#  {'location_id': '1344203',
#   'applicant': 'Bay Area Dots, LLC',
#   'facility_type': 'Push Cart',
#   'cnn': 25524000,
#   'location_description': 'TAYLOR ST: BAY ST intersection',
#   'address': '567 BAY ST',
#   'blocklot': '0043001',
#   'block': '0043',
#   'lot': '001',
#   'permit': '19MFF-00117',
#   'status': 'REQUESTED',
#   'food_items': 'Hot dogs: condiments: soft pretzels: soft drinks: coffee: cold beverages: pastries: bakery goods: cookies: ice cream: candy: soups: churros: chestnuts: nuts: fresh fruit: fruit juices: desserts: potato chips and popcorn.',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00117&ExportPDF=1&Filename=19MFF-00117_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190802',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2020, 7, 15, 0, 0)},
#  {'location_id': '1400796',
#   'applicant': 'El Calamar Perubian Food Truck',
#   'facility_type': 'Truck',
#   'cnn': 1329000,
#   'location_description': '24TH ST: UTAH ST to POTRERO AVE (2600 - 2699)',
#   'address': '2615 24TH ST',
#   'blocklot': '4264019A',
#   'block': '4264',
#   'lot': '019A',
#   'permit': '20MFF-00002',
#   'status': 'REQUESTED',
#   'food_items': 'Lomo Saltado: Jalea: Ceviche: Calamari Tilapia Plates: Chicken: Soda: Water.',
#   'x': 6010762.925,
#   'y': 2102188.055,
#   'latitude': 37.75281482922111,
#   'longitude': -122.40566264191837,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=20MFF-00002&ExportPDF=1&Filename=20MFF-00002_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20200127',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2021, 1, 31, 0, 0)},
#  {'location_id': '934553',
#   'applicant': "Casey's Pizza, LLC",
#   'facility_type': 'Truck',
#   'cnn': 10624001,
#   'location_description': 'POST ST: MONTGOMERY ST to LICK PL (1 - 40)',
#   'address': '1 POST ST',
#   'blocklot': '0311015',
#   'block': '0311',
#   'lot': '015',
#   'permit': '17MFF-0104',
#   'status': 'EXPIRED',
#   'food_items': "Artisan Pizzas (Margherita: Yukon Potato: Zoe's Pepperoni: Funghi: Brocolli Rabe: Bacon Kale:  Arugula) and Drinks.",
#   'x': 6011921.732,
#   'y': 2115262.393,
#   'latitude': 37.788778723377995,
#   'longitude': -122.40257456841074,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0104&ExportPDF=1&Filename=17MFF-0104_schedule.pdf',
#   'dayshours': 'Sa:12PM-4PM;Tu/We/Th:3PM-8PM',
#   'approved': datetime.datetime(2017, 8, 29, 0, 0),
#   'received': '20170213',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2018, 7, 15, 0, 0)},
#  {'location_id': '1337786',
#   'applicant': 'Giant Burrito',
#   'facility_type': 'Truck',
#   'cnn': 2800102,
#   'location_description': 'BAY SHORE BLVD: FLOWER ST to CORTLAND AVE (341 - 489) -- EAST --',
#   'address': '353 BAY SHORE BLVD',
#   'blocklot': '5598030',
#   'block': '5598',
#   'lot': '030',
#   'permit': '19MFF-00088',
#   'status': 'REQUESTED',
#   'food_items': 'Tacos: Burritos: Tostadas: Flautas: Tostadas: Tortas: Pozole Menudo',
#   'x': 6010751.382,
#   'y': 2098146.819,
#   'latitude': 37.74171783074393,
#   'longitude': -122.40541797744821,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=19MFF-00088&ExportPDF=1&Filename=19MFF-00088_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20190715',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 7, 15, 0, 0)},
#  {'location_id': '1416733',
#   'applicant': 'Off the Grid Services, LLC',
#   'facility_type': 'Truck',
#   'cnn': 11542000,
#   'location_description': 'SANSOME ST: SUTTER ST to BUSH ST (1 - 99)',
#   'address': '1 BUSH ST',
#   'blocklot': '0290011',
#   'block': '0290',
#   'lot': '011',
#   'permit': '20MFF-00003',
#   'status': 'REQUESTED',
#   'food_items': None,
#   'x': 6012652.373,
#   'y': 2116027.943,
#   'latitude': 37.79092150726921,
#   'longitude': -122.4001004237385,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=20MFF-00003&ExportPDF=1&Filename=20MFF-00003_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20200331',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2020, 7, 15, 0, 0)},
#  {'location_id': '1514024',
#   'applicant': 'F & C Catering',
#   'facility_type': 'Truck',
#   'cnn': 0,
#   'location_description': None,
#   'address': 'Assessors Block /Lot',
#   'blocklot': None,
#   'block': None,
#   'lot': None,
#   'permit': '21MFF-00035',
#   'status': 'EXPIRED',
#   'food_items': 'Cold Truck: Hot/Cold Sandwiches: Water: Soda: Juice: Snacks: Milk: Candies: Canned Food: Soups: Cup of Noodles: Fruit: Salad',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=21MFF-00035&ExportPDF=1&Filename=21MFF-00035_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2021, 3, 30, 0, 0),
#   'received': '20210326',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2021, 11, 15, 0, 0)},
#  {'location_id': '1034228',
#   'applicant': "Julie's Hot Dogs",
#   'facility_type': None,
#   'cnn': 9114000,
#   'location_description': 'MISSION ST: 14TH ST to 15TH ST (1800 - 1899)',
#   'address': '1850 MISSION ST',
#   'blocklot': '3547261',
#   'block': '3547',
#   'lot': '261',
#   'permit': '17MFF-0196',
#   'status': 'REQUESTED',
#   'food_items': 'Hot dogs: bacon wrap hot dogs: chicken burgers: energy drinks: water & various drinks',
#   'x': 6006577.68992,
#   'y': 2107569.10778,
#   'latitude': 37.76735502136977,
#   'longitude': -122.42051791382852,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0196&ExportPDF=1&Filename=17MFF-0196_schedule.pdf',
#   'dayshours': 'Su/Fr/Sa:7AM-5PM',
#   'approved': None,
#   'received': '20171027',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1591997',
#   'applicant': 'Lerso',
#   'facility_type': 'Truck',
#   'cnn': 9108000,
#   'location_description': 'MISSION ST: 10TH ST to 11TH ST (1400 - 1499)',
#   'address': '1450 MISSION ST',
#   'blocklot': '3507040',
#   'block': '3507',
#   'lot': '040',
#   'permit': '22MFF-00026',
#   'status': 'SUSPEND',
#   'food_items': 'Pernil Asado: Ropa Vieja: Arroz con Pollo: Cuban Sandwich: Croquetas Fritas: Tostones: Platanos Maduros: Yuca Frita',
#   'x': 6007518.36,
#   'y': 2110417.248,
#   'latitude': 37.77522830783405,
#   'longitude': -122.41746613186956,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=22MFF-00026&ExportPDF=1&Filename=22MFF-00026_schedule.pdf',
#   'dayshours': None,
#   'approved': None,
#   'received': '20220126',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2022, 11, 15, 0, 0)},
#  {'location_id': '963993',
#   'applicant': 'Singh Brothers Ice Cream',
#   'facility_type': 'Truck',
#   'cnn': 11783000,
#   'location_description': 'SHAFTER AVE: HAWES ST to INGALLS ST (1200 - 1299)',
#   'address': '1207 SHAFTER AVE',
#   'blocklot': '4792001A',
#   'block': '4792',
#   'lot': '001A',
#   'permit': '17MFF-0182',
#   'status': 'REQUESTED',
#   'food_items': 'Ice Cream: Pre-Packaged Chips: Candies: Bottled Water & Canned SODA',
#   'x': 6016941.58,
#   'y': 2092555.108,
#   'latitude': 37.726708272962156,
#   'longitude': -122.38362491720036,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0182&ExportPDF=1&Filename=17MFF-0182_schedule.pdf',
#   'dayshours': 'Mo-Fr:3PM-4PM',
#   'approved': None,
#   'received': '20170418',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2018, 3, 15, 0, 0)},
#  {'location_id': '1741557',
#   'applicant': 'Philz Coffee Truck',
#   'facility_type': 'Truck',
#   'cnn': 9306000,
#   'location_description': 'MONTGOMERY ST: COLUMBUS AVE \\ WASHINGTON ST to JACKSON ST (700 - 799)',
#   'address': '735 MONTGOMERY ST',
#   'blocklot': '0195001',
#   'block': '0195',
#   'lot': '001',
#   'permit': '23MFF-00045',
#   'status': 'APPROVED',
#   'food_items': 'Hot coffee: iced coffee: hot chocolate: tea: pastries',
#   'x': 6011635.905,
#   'y': 2117976.662,
#   'latitude': 37.79621549659414,
#   'longitude': -122.40375455824538,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00045&ExportPDF=1&Filename=23MFF-00045_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2023, 11, 15, 0, 0),
#   'received': '20231115',
#   'prior_permit': False,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '963978',
#   'applicant': 'Singh Brothers Ice Cream',
#   'facility_type': 'Truck',
#   'cnn': 6961000,
#   'location_description': 'HOLLISTER AVE: HAWES ST to INGALLS ST (1000 - 1099)',
#   'address': '1000 HOLLISTER AVE',
#   'blocklot': '4943002',
#   'block': '4943',
#   'lot': '002',
#   'permit': '17MFF-0182',
#   'status': 'REQUESTED',
#   'food_items': 'Ice Cream: Pre-Packaged Chips: Candies: Bottled Water & Canned SODA',
#   'x': 6014891.341,
#   'y': 2089767.246,
#   'latitude': 37.718939819095944,
#   'longitude': -122.39051787206593,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=17MFF-0182&ExportPDF=1&Filename=17MFF-0182_schedule.pdf',
#   'dayshours': 'Mo-Fr:12PM-1PM',
#   'approved': None,
#   'received': '20170418',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2018, 3, 15, 0, 0)},
#  {'location_id': '1153604',
#   'applicant': 'SPUNBYSS',
#   'facility_type': 'Truck',
#   'cnn': 136000,
#   'location_description': '02ND ST: TEHAMA ST to CLEMENTINA ST (224 - 273)',
#   'address': '240 02ND ST',
#   'blocklot': '3735055',
#   'block': '3735',
#   'lot': '055',
#   'permit': '18MFF-0021',
#   'status': 'REQUESTED',
#   'food_items': 'American classic slider:  fried chicken slider: fried chicken skin: wedge cut fries: regular cut fries: handcrafted sodas: spring salad',
#   'x': 6013280.206,
#   'y': 2114201.068,
#   'latitude': 37.78594032017338,
#   'longitude': -122.39779993385848,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=18MFF-0021&ExportPDF=1&Filename=18MFF-0021_schedule.pdf',
#   'dayshours': 'Mo/We/Fr:10AM-2PM',
#   'approved': None,
#   'received': '20180430',
#   'prior_permit': False,
#   'expiration_date': None},
#  {'location_id': '1723823',
#   'applicant': "Natan's Catering",
#   'facility_type': 'Truck',
#   'cnn': 7166000,
#   'location_description': 'ILLINOIS ST: MARIPOSA ST \\ TERRY A FRANCOIS BLVD to 18TH ST (600 - 699)',
#   'address': 'Assessors Block 3941/Lot001',
#   'blocklot': '3941001',
#   'block': '3941',
#   'lot': '001',
#   'permit': '23MFF-00006',
#   'status': 'APPROVED',
# ...
#   'lot': '013',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015941.755,
#   'y': 2091544.796,
#   'latitude': 37.72387884083248,
#   'longitude': -122.3870108787852,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750865',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 7479000,
#   'location_description': 'JENNINGS ST: VAN DYKE AVE to WALLACE AVE (2100 - 2199)',
#   'address': '2115 JENNINGS ST',
#   'blocklot': '4828021',
#   'block': '4828',
#   'lot': '021',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015486.282,
#   'y': 2092591.619,
#   'latitude': 37.72672797825706,
#   'longitude': -122.38865842883155,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750859',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 4908000,
#   'location_description': 'DONNER AVE: INGALLS ST to JENNINGS ST (1400 - 1499)',
#   'address': '1450 DONNER AVE',
#   'blocklot': '4882025',
#   'block': '4882',
#   'lot': '025',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6014749.836,
#   'y': 2091269.372,
#   'latitude': 37.72305650933894,
#   'longitude': -122.39111194064196,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750849',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 13355000,
#   'location_description': 'WALLACE AVE: INGALLS ST to JENNINGS ST (1400 - 1499)',
#   'address': '1450 WALLACE AVE',
#   'blocklot': '4828024',
#   'block': '4828',
#   'lot': '024',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015606.538,
#   'y': 2092377.128,
#   'latitude': 37.72614569247294,
#   'longitude': -122.38822774090347,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750852',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 13780000,
#   'location_description': 'YOSEMITE AVE: INGALLS ST to JENNINGS ST (1400 - 1499)',
#   'address': '1420 YOSEMITE AVE',
#   'blocklot': '4831012',
#   'block': '4831',
#   'lot': '012',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015609.592,
#   'y': 2092025.988,
#   'latitude': 37.725181700728754,
#   'longitude': -122.38819268844395,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750839',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 10972000,
#   'location_description': 'REVERE AVE: GRIFFITH ST to CRISP RD (1100 - 1188)',
#   'address': '1160 REVERE AVE',
#   'blocklot': '4763050',
#   'block': '4763',
#   'lot': '050',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6017468.62,
#   'y': 2092735.972,
#   'latitude': 37.727234007495866,
#   'longitude': -122.38181551187014,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750855',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 2709000,
#   'location_description': 'BANCROFT AVE: INGALLS ST to JENNINGS ST (1400 - 1499)',
#   'address': '1460 BANCROFT AVE',
#   'blocklot': '4850038',
#   'block': '4850',
#   'lot': '038',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015035.87862,
#   'y': 2091757.70466,
#   'latitude': 37.72441324329633,
#   'longitude': -122.39015723961076,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750862',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 6540000,
#   'location_description': 'GRIFFITH ST: QUESADA AVE to REVERE AVE (1300 - 1399)',
#   'address': '1300 GRIFFITH ST',
#   'blocklot': '4763047',
#   'block': '4763',
#   'lot': '047',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6017681.819,
#   'y': 2092678.013,
#   'latitude': 37.727086633951366,
#   'longitude': -122.38107444874923,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750847',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 13139000,
#   'location_description': 'VAN DYKE AVE: INGALLS ST to JENNINGS ST (1300 - 1399)',
#   'address': '1370 VAN DYKE AVE',
#   'blocklot': '4811013',
#   'block': '4811',
#   'lot': '013',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015684.099,
#   'y': 2092668.764,
#   'latitude': 37.72695076437817,
#   'longitude': -122.3879799562619,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750867',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 9743000,
#   'location_description': 'OFARRELL ST: BRODERICK ST to SAINT JOSEPHS AVE (2200 - 2299)',
#   'address': '2200 OFARRELL ST',
#   'blocklot': '1098044',
#   'block': '1098',
#   'lot': '044',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': None,
#   'y': None,
#   'latitude': 0.0,
#   'longitude': 0.0,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750850',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 13356000,
#   'location_description': 'WALLACE AVE: JENNINGS ST to KEITH ST (1500 - 1599)',
#   'address': '1500 WALLACE AVE',
#   'blocklot': '4829002',
#   'block': '4829',
#   'lot': '002',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015315.254,
#   'y': 2092594.276,
#   'latitude': 37.726725793811774,
#   'longitude': -122.38924985802704,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750853',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 13780000,
#   'location_description': 'YOSEMITE AVE: INGALLS ST to JENNINGS ST (1400 - 1499)',
#   'address': '1430 YOSEMITE AVE',
#   'blocklot': '4831008',
#   'block': '4831',
#   'lot': '008',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6015560.891,
#   'y': 2092142.182,
#   'latitude': 37.72549804795053,
#   'longitude': -122.38836915044175,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750857',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 2866000,
#   'location_description': 'BEALE ST: FOLSOM ST to HARRISON ST (300 - 399)',
#   'address': '300 BEALE ST',
#   'blocklot': '3747022',
#   'block': '3747',
#   'lot': '022',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6014804.68,
#   'y': 2114971.118,
#   'latitude': 37.78813947887162,
#   'longitude': -122.39257951537353,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750856',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 2710000,
#   'location_description': 'BANCROFT AVE: JENNINGS ST to KEITH ST (1500 - 1599)',
#   'address': '1555 BANCROFT AVE',
#   'blocklot': '4880001',
#   'block': '4880',
#   'lot': '001',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6014646.012,
#   'y': 2091759.86,
#   'latitude': 37.72439752974338,
#   'longitude': -122.39150511638297,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750860',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 5452000,
#   'location_description': 'FELL ST: BRODERICK ST to BAKER ST (1300 - 1399)',
#   'address': '1377 FELL ST',
#   'blocklot': '1214017',
#   'block': '1214',
#   'lot': '017',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6000983.009,
#   'y': 2109845.279,
#   'latitude': 37.773287940470354,
#   'longitude': -122.44003231663504,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750861',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 5862000,
#   'location_description': 'FREMONT ST: NATOMA ST to HOWARD ST (170 - 199)',
#   'address': 'Assessors Block 3720/Lot001',
#   'blocklot': '3720001',
#   'block': '3720',
#   'lot': '001',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6013655.829,
#   'y': 2115559.572,
#   'latitude': 37.78969136758703,
#   'longitude': -122.39659563708379,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750835',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 10215000,
#   'location_description': 'PALOU AVE: PALOU AVE to GRIFFITH ST (904 - 999)',
#   'address': '931 PALOU AVE',
#   'blocklot': '4755042',
#   'block': '4755',
#   'lot': '042',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6018287.161,
#   'y': 2092537.392,
#   'latitude': 37.72673391124156,
#   'longitude': -122.37897200523552,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)},
#  {'location_id': '1750864',
#   'applicant': 'TING TING MINI MOBILE DELI',
#   'facility_type': 'Truck',
#   'cnn': 6792000,
#   'location_description': 'HAWES ST: SHAFTER AVE to THOMAS AVE (1500 - 1599)',
#   'address': '1153 SHAFTER AVE',
#   'blocklot': '4793006',
#   'block': '4793',
#   'lot': '006',
#   'permit': '23MFF-00054',
#   'status': 'APPROVED',
#   'food_items': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#   'x': 6017053.425,
#   'y': 2092471.602,
#   'latitude': 37.72648516321647,
#   'longitude': -122.38323245870731,
#   'schedule': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf',
#   'dayshours': None,
#   'approved': datetime.datetime(2024, 3, 28, 0, 0),
#   'received': '20231229',
#   'prior_permit': True,
#   'expiration_date': datetime.datetime(2024, 11, 15, 0, 0)}]

# %%
from sqlalchemy import create_engine
# Connect to the DB and insert data
engine = create_engine('mysql+mysqlconnector://root:root@localhost/food_trucks', connect_args={'connect_timeout': 10000})
df = pd.DataFrame(output_data)
df.set_index('location_id')
df.to_sql('food_trucks', con=engine, if_exists='append', index=False, method='multi')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     696                 query = query.encode("utf-8")
# --> 697             self._cmysql.query(
#     698                 query,
#
# MySQLInterfaceError: Duplicate entry '735318' for key 'food_trucks.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1966                 if not evt_handled:
# -> 1967                     self.dialect.do_execute(
#    1968                         cursor, str_statement, effective_parameters, context
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     923     def do_execute(self, cursor, statement, parameters, context=None):
# --> 924         cursor.execute(statement, parameters)
#     925
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     371         try:
# --> 372             result = self._cnx.cmd_query(
#     373                 stmt,
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/opentelemetry/context_propagation.py in wrapper(cnx, *args, **kwargs)
#     101         if not OTEL_ENABLED or not cnx.otel_context_propagation:
# --> 102             return method(cnx, *args, **kwargs)
#     103
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     704         except MySQLInterfaceError as err:
# --> 705             raise get_mysql_exception(
#     706                 err.errno, msg=err.msg, sqlstate=err.sqlstate
#
# IntegrityError: 1062 (23000): Duplicate entry '735318' for key 'food_trucks.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /tmp/ipykernel_81920/2544509457.py in <module>
#       4 df = pd.DataFrame(output_data)
#       5 df.set_index('location_id')
# ----> 6 df.to_sql('food_trucks', con=engine, if_exists='append', index=False, method='multi')
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2985         from pandas.io import sql
#    2986
# -> 2987         return sql.to_sql(
#    2988             self,
#    2989             name,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693         )
#     694
# --> 695     return pandas_sql.to_sql(
#     696         frame,
#     697         name,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1736         )
#    1737
# -> 1738         total_inserted = sql_engine.insert_records(
#    1739             table=table,
#    1740             con=self.connectable,
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1333                 raise ValueError("inf cannot be used with MySQL") from err
#    1334             else:
# -> 1335                 raise err
#    1336
#    1337
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1323
#    1324         try:
# -> 1325             return table.insert(chunksize=chunksize, method=method)
#    1326         except exc.SQLAlchemyError as err:
#    1327             # GH34431
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     944
#     945                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 946                 num_inserted = exec_insert(conn, keys, chunk_iter)
#     947                 # GH 46891
#     948                 if is_integer(num_inserted):
#
# ~/.local/lib/python3.10/site-packages/pandas/io/sql.py in _execute_insert_multi(self, conn, keys, data_iter)
#     867         data = [dict(zip(keys, row)) for row in data_iter]
#     868         stmt = insert(self.table).values(data)
# --> 869         result = conn.execute(stmt)
#     870         return result.rowcount
#     871
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1416             raise exc.ObjectNotExecutableError(statement) from err
#    1417         else:
# -> 1418             return meth(
#    1419                 self,
#    1420                 distilled_parameters,
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, distilled_params, execution_options)
#     513             if TYPE_CHECKING:
#     514                 assert isinstance(self, Executable)
# --> 515             return connection._execute_clauseelement(
#     516                 self, distilled_params, execution_options
#     517             )
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1638             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639         )
# -> 1640         ret = self._execute_context(
#    1641             dialect,
#    1642             dialect.execution_ctx_cls._init_compiled,
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844             return self._exec_insertmany_context(dialect, context)
#    1845         else:
# -> 1846             return self._exec_single_context(
#    1847                 dialect, context, statement, parameters
#    1848             )
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1984
#    1985         except BaseException as e:
# -> 1986             self._handle_dbapi_exception(
#    1987                 e, str_statement, effective_parameters, cursor, context
#    1988             )
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351             elif should_wrap:
#    2352                 assert sqlalchemy_exception is not None
# -> 2353                 raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354             else:
#    2355                 assert exc_info[1] is not None
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in _exec_single_context(self, dialect, context, statement, parameters)
#    1965                             break
#    1966                 if not evt_handled:
# -> 1967                     self.dialect.do_execute(
#    1968                         cursor, str_statement, effective_parameters, context
#    1969                     )
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     922
#     923     def do_execute(self, cursor, statement, parameters, context=None):
# --> 924         cursor.execute(statement, parameters)
#     925
#     926     def do_execute_no_params(self, cursor, statement, context=None):
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     370
#     371         try:
# --> 372             result = self._cnx.cmd_query(
#     373                 stmt,
#     374                 raw=self._raw,
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/opentelemetry/context_propagation.py in wrapper(cnx, *args, **kwargs)
#     100         """Context propagation decorator."""
#     101         if not OTEL_ENABLED or not cnx.otel_context_propagation:
# --> 102             return method(cnx, *args, **kwargs)
#     103
#     104         current_span = trace.get_current_span()
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     703             )
#     704         except MySQLInterfaceError as err:
# --> 705             raise get_mysql_exception(
#     706                 err.errno, msg=err.msg, sqlstate=err.sqlstate
#     707             ) from err
#
# IntegrityError: (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '735318' for key 'food_trucks.PRIMARY'
# [SQL: INSERT INTO food_trucks (location_id, applicant, facility_type, cnn, location_description, address, blocklot, block, lot, permit, status, food_items, x, y, latitude, longitude, schedule, dayshours, approved, received, prior_permit, expiration_date) VALUES (%(location_id_m0)s, %(applicant_m0)s, %(facility_type_m0)s, %(cnn_m0)s, %(location_description_m0)s, %(address_m0)s, %(blocklot_m0)s, %(block_m0)s, %(lot_m0)s, %(permit_m0)s, %(status_m0)s, %(food_items_m0)s, %(x_m0)s, %(y_m0)s, %(latitude_m0)s, %(longitude_m0)s, %(schedule_m0)s, %(dayshours_m0)s, %(approved_m0)s, %(received_m0)s, %(prior_permit_m0)s, %(expiration_date_m0)s), (%(location_id_m1)s, %(applicant_m1)s, %(facility_type_m1)s, %(cnn_m1)s, %(location_description_m1)s, %(address_m1)s, %(blocklot_m1)s, %(block_m1)s, %(lot_m1)s, %(permit_m1)s, %(status_m1)s, %(food_items_m1)s, %(x_m1)s, %(y_m1)s, %(latitude_m1)s, %(longitude_m1)s, %(schedule_m1)s, %(dayshours_m1)s, %(approved_m1)s, %(received_m1)s, %(prior_permit_m1)s, %(expiration_date_m1)s), (%(location_id_m2)s, %(applicant_m2)s, %(facility_type_m2)s, %(cnn_m2)s, %(location_description_m2)s, %(address_m2)s, %(blocklot_m2)s, %(block_m2)s, %(lot_m2)s, %(permit_m2)s, %(status_m2)s, %(food_items_m2)s, %(x_m2)s, %(y_m2)s, %(latitude_m2)s, %(longitude_m2)s, %(schedule_m2)s, %(dayshours_m2)s, %(approved_m2)s, %(received_m2)s, %(prior_permit_m2)s, %(expiration_date_m2)s), (%(location_id_m3)s, %(applicant_m3)s, %(facility_type_m3)s, %(cnn_m3)s, %(location_description_m3)s, %(address_m3)s, %(blocklot_m3)s, %(block_m3)s, %(lot_m3)s, %(permit_m3)s, %(status_m3)s, %(food_items_m3)s, %(x_m3)s, %(y_m3)s, %(latitude_m3)s, %(longitude_m3)s, %(schedule_m3)s, %(dayshours_m3)s, %(approved_m3)s, %(received_m3)s, %(prior_permit_m3)s, %(expiration_date_m3)s), (%(location_id_m4)s, %(applicant_m4)s, %(facility_type_m4)s, %(cnn_m4)s, %(location_description_m4)s, %(address_m4)s, %(blocklot_m4)s, %(block_m4)s, %(lot_m4)s, %(permit_m4)s, %(status_m4)s, %(food_items_m4)s, %(x_m4)s, %(y_m4)s, %(latitude_m4)s, %(longitude_m4)s, %(schedule_m4)s, %(dayshours_m4)s, %(approved_m4)s, %(received_m4)s, %(prior_permit_m4)s, %(expiration_date_m4)s), (%(location_id_m5)s, %(applicant_m5)s, %(facility_type_m5)s, %(cnn_m5)s, %(location_description_m5)s, %(address_m5)s, %(blocklot_m5)s, %(block_m5)s, %(lot_m5)s, %(permit_m5)s, %(status_m5)s, %(food_items_m5)s, %(x_m5)s, %(y_m5)s, %(latitude_m5)s, %(longitude_m5)s, %(schedule_m5)s, %(dayshours_m5)s, %(approved_m5)s, %(received_m5)s, %(prior_permit_m5)s, %(expiration_date_m5)s), (%(location_id_m6)s, %(applicant_m6)s, %(facility_type_m6)s, %(cnn_m6)s, %(location_description_m6)s, %(address_m6)s, %(blocklot_m6)s, %(block_m6)s, %(lot_m6)s, %(permit_m6)s, %(status_m6)s, %(food_items_m6)s, %(x_m6)s, %(y_m6)s, %(latitude_m6)s, %(longitude_m6)s, %(schedule_m6)s, %(dayshours_m6)s, %(approved_m6)s, %(received_m6)s, %(prior_permit_m6)s, %(expiration_date_m6)s), (%(location_id_m7)s, %(applicant_m7)s, %(facility_type_m7)s, %(cnn_m7)s, %(location_description_m7)s, %(address_m7)s, %(blocklot_m7)s, %(block_m7)s, %(lot_m7)s, %(permit_m7)s, %(status_m7)s, %(food_items_m7)s, %(x_m7)s, %(y_m7)s, %(latitude_m7)s, %(longitude_m7)s, %(schedule_m7)s, %(dayshours_m7)s, %(approved_m7)s, %(received_m7)s, %(prior_permit_m7)s, %(expiration_date_m7)s), (%(location_id_m8)s, %(applicant_m8)s, %(facility_type_m8)s, %(cnn_m8)s, %(location_description_m8)s, %(address_m8)s, %(blocklot_m8)s, %(block_m8)s, %(lot_m8)s, %(permit_m8)s, %(status_m8)s, %(food_items_m8)s, %(x_m8)s, %(y_m8)s, %(latitude_m8)s, %(longitude_m8)s, %(schedule_m8)s, %(dayshours_m8)s, %(approved_m8)s, %(received_m8)s, %(prior_permit_m8)s, %(expiration_date_m8)s), (%(location_id_m9)s, %(applicant_m9)s, %(facility_type_m9)s, %(cnn_m9)s, %(location_description_m9)s, %(address_m9)s, %(blocklot_m9)s, %(block_m9)s, %(lot_m9)s, %(permit_m9)s, %(status_m9)s, %(food_items_m9)s, %(x_m9)s, %(y_m9)s, %(latitude_m9)s, %(longitude_m9)s, %(schedule_m9)s, %(dayshours_m9)s, %(approved_m9)s, % ...
# [parameters: {'location_id_m0': '735318', 'applicant_m0': 'Ziaurehman Amini', 'facility_type_m0': 'Push Cart', 'cnn_m0': 30727000, 'location_description_m0': 'MARKET ST: DRUMM ST intersection', 'address_m0': '5 THE EMBARCADERO', 'blocklot_m0': '0234017', 'block_m0': '0234', 'lot_m0': '017', 'permit_m0': '15MFF-0159', 'status_m0': 'REQUESTED', 'food_items_m0': None, 'x_m0': 6013916.72, 'y_m0': 2117244.027, 'latitude_m0': 37.794331003246846, 'longitude_m0': -122.39581105302317, 'schedule_m0': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=15MFF-0159&ExportPDF=1&Filename=15MFF-0159_schedule.pdf', 'dayshours_m0': None, 'approved_m0': None, 'received_m0': '20151231', 'prior_permit_m0': 0, 'expiration_date_m0': datetime.datetime(2016, 3, 15, 0, 0), 'location_id_m1': '848184', 'applicant_m1': 'Reecees Soulicious', 'facility_type_m1': 'Truck', 'cnn_m1': 2799106, 'location_description_m1': 'BAY SHORE BLVD: BAY SHORE BLVD to OAKDALE AVE (185 - 299) -- EAST --', 'address_m1': '201 BAY SHORE BLVD', 'blocklot_m1': '5559021', 'block_m1': '5559', 'lot_m1': '021', 'permit_m1': '16MFF-0139', 'status_m1': 'REQUESTED', 'food_items_m1': 'Fried Chicken: Fried Fish: Greens: Mac & Cheese: Peach Cobbler: and String beans', 'x_m1': 6011355.555, 'y_m1': 2099442.374, 'latitude_m1': 37.74530890865633, 'longitude_m1': -122.40342005999852, 'schedule_m1': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=16MFF-0139&ExportPDF=1&Filename=16MFF-0139_schedule.pdf', 'dayshours_m1': 'Mo-We:7AM-7PM', 'approved_m1': None, 'received_m1': '20160908', 'prior_permit_m1': 0, 'expiration_date_m1': datetime.datetime(2017, 3, 15, 0, 0), 'location_id_m2': '1047831', 'applicant_m2': 'The Chef Station', 'facility_type_m2': 'Truck', 'cnn_m2': 480000, 'location_description_m2': '10TH ST: FELL ST \\ MARKET ST \\ POLK ST to STEVENSON ST (1 - 18)', 'address_m2': '8 10TH ST' ... 10482 parameters truncated ... 'schedule_m478': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf', 'dayshours_m478': None, 'approved_m478': datetime.datetime(2024, 3, 28, 0, 0), 'received_m478': '20231229', 'prior_permit_m478': 1, 'expiration_date_m478': datetime.datetime(2024, 11, 15, 0, 0), 'location_id_m479': '1750835', 'applicant_m479': 'TING TING MINI MOBILE DELI', 'facility_type_m479': 'Truck', 'cnn_m479': 10215000, 'location_description_m479': 'PALOU AVE: PALOU AVE to GRIFFITH ST (904 - 999)', 'address_m479': '931 PALOU AVE', 'blocklot_m479': '4755042', 'block_m479': '4755', 'lot_m479': '042', 'permit_m479': '23MFF-00054', 'status_m479': 'APPROVED', 'food_items_m479': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages', 'x_m479': 6018287.161, 'y_m479': 2092537.392, 'latitude_m479': 37.72673391124156, 'longitude_m479': -122.37897200523552, 'schedule_m479': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx?title=schedule&report=rptSchedule&params=permit=23MFF-00054&ExportPDF=1&Filename=23MFF-00054_schedule.pdf', 'dayshours_m479': None, 'approved_m479': datetime.datetime(2024, 3, 28, 0, 0), 'received_m479': '20231229', 'prior_permit_m479': 1, 'expiration_date_m479': datetime.datetime(2024, 11, 15, 0, 0), 'location_id_m480': '1750864', 'applicant_m480': 'TING TING MINI MOBILE DELI', 'facility_type_m480': 'Truck', 'cnn_m480': 6792000, 'location_description_m480': 'HAWES ST: SHAFTER AVE to THOMAS AVE (1500 - 1599)', 'address_m480': '1153 SHAFTER AVE', 'blocklot_m480': '4793006', 'block_m480': '4793', 'lot_m480': '006', 'permit_m480': '23MFF-00054', 'status_m480': 'APPROVED', 'food_items_m480': 'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages', 'x_m480': 6017053.425, 'y_m480': 2092471.602, 'latitude_m480': 37.72648516321647, 'longitude_m480': -122.38323245870731, 'schedule_m480': 'http://bsm.sfdpw.org/PermitsTracker/reports/report.aspx? ...
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
